# %% [markdown]
# ## Bigquery
#
# * BigQuery is a fully managed data warehouse that helps you manage and analyze your data with built-in features like machine learning, geospatial analysis, and business intelligence.
# * BigQuery is a serverless and cost-effective data warehouse that works across clouds and scales with your data.
# * Developers and data scientists can use client libraries with familiar programming including Python, Java, JavaScript, and Go, as well as BigQuery's REST API and RPC API to transform and manage data.

# %%
# Install google-cloud-bigquery client library for python
#pip install google-cloud-bigquery

# %%
# Out:
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# c:\Users\smvin\Documents\Python_training\Day8\GCP_Bigquery.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=23'>24</a>         print("{} : {} views".format(row.url, row.view_count))
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=26'>27</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=27'>28</a>     query_stackoverflow()
#
# c:\Users\smvin\Documents\Python_training\Day8\GCP_Bigquery.ipynb Cell 3 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> project_id = "bamboo-bulwark-319114"
#       <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> client = bigquery.Client(project_id)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> query_job = client.query(
#       <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>     """
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     SELECT
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>       CONCAT(
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>         'https://stackoverflow.com/questions/',
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>         CAST(id as STRING)) as url,
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a>       view_count
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a>     FROM `bigquery-public-data.stackoverflow.posts_questions`
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a>     WHERE tags like '%google-bigquery%'
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a>     ORDER BY view_count DESC
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a>     LIMIT 10"""
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a> results = query_job.result()  # Waits for job to complete.
#      <a href='vscode-notebook-cell:/c%3A/Users/smvin/Documents/Python_training/Day8/GCP_Bigquery.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a> for row in results:
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\cloud\bigquery\client.py:3411, in Client.query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method)
#    3400     return _job_helpers.query_jobs_query(
#    3401         self,
#    3402         query,
#    (...)
#    3408         job_retry,
#    3409     )
#    3410 elif api_method == enums.QueryApiMethod.INSERT:
# -> 3411     return _job_helpers.query_jobs_insert(
#    3412         self,
#    3413         query,
#    3414         job_config,
#    3415         job_id,
#    3416         job_id_prefix,
#    3417         location,
#    3418         project,
#    3419         retry,
#    3420         timeout,
#    3421         job_retry,
#    3422     )
#    3423 else:
#    3424     raise ValueError(f"Got unexpected value for api_method: {repr(api_method)}")
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\cloud\bigquery\_job_helpers.py:114, in query_jobs_insert(client, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry)
#     111     else:
#     112         return query_job
# --> 114 future = do_query()
#     115 # The future might be in a failed state now, but if it's
#     116 # unrecoverable, we'll find out when we ask for it's result, at which
#     117 # point, we may retry.
#     118 if not job_id_given:
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\cloud\bigquery\_job_helpers.py:91, in query_jobs_insert.<locals>.do_query()
#      88 query_job = job.QueryJob(job_ref, query, client=client, job_config=job_config)
#      90 try:
# ---> 91     query_job._begin(retry=retry, timeout=timeout)
#      92 except core_exceptions.Conflict as create_exc:
#      93     # The thought is if someone is providing their own job IDs and they get
#      94     # their job ID generation wrong, this could end up returning results for
#      95     # the wrong query. We thus only try to recover if job ID was not given.
#      96     if job_id_given:
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\cloud\bigquery\job\query.py:1371, in QueryJob._begin(self, client, retry, timeout)
#    1351 """API call:  begin the job via a POST request
#    1352
#    1353 See
#    (...)
#    1367     ValueError: If the job has already begun.
#    1368 """
#    1370 try:
# -> 1371     super(QueryJob, self)._begin(client=client, retry=retry, timeout=timeout)
#    1372 except exceptions.GoogleAPICallError as exc:
#    1373     exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#    1374         message=exc.message, location=self.location, job_id=self.job_id
#    1375     )
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\cloud\bigquery\job\base.py:693, in _AsyncJob._begin(self, client, retry, timeout)
#     690 # jobs.insert is idempotent because we ensure that every new
#     691 # job has an ID.
#     692 span_attributes = {"path": path}
# --> 693 api_response = client._call_api(
#     694     retry,
#     695     span_name="BigQuery.job.begin",
#     696     span_attributes=span_attributes,
#     697     job_ref=self,
#     698     method="POST",
#     699     path=path,
#     700     data=self.to_api_repr(),
#     701     timeout=timeout,
#     702 )
#     703 self._set_properties(api_response)
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\cloud\bigquery\client.py:816, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     812 if span_name is not None:
#     813     with create_span(
#     814         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     815     ):
# --> 816         return call()
#     818 return call()
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\api_core\retry.py:366, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     362 target = functools.partial(func, *args, **kwargs)
#     363 sleep_generator = exponential_sleep_generator(
#     364     self._initial, self._maximum, multiplier=self._multiplier
#     365 )
# --> 366 return retry_target(
#     367     target,
#     368     self._predicate,
#     369     sleep_generator,
#     370     self._timeout,
#     371     on_error=on_error,
#     372 )
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\api_core\retry.py:204, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     202 for sleep in sleep_generator:
#     203     try:
# --> 204         return target()
#     206     # pylint: disable=broad-except
#     207     # This function explicitly must deal with broad exceptions.
#     208     except Exception as exc:
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\cloud\_http\__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     479     data = json.dumps(data)
#     480     content_type = "application/json"
# --> 482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#     485     data=data,
#     486     content_type=content_type,
#     487     headers=headers,
#     488     target_object=_target_object,
#     489     timeout=timeout,
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
#     494     raise exceptions.from_http_response(response)
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\cloud\_http\__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#     339 headers["User-Agent"] = self.user_agent
# --> 341 return self._do_request(
#     342     method, url, headers, data, target_object, timeout=timeout
#     343 )
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\cloud\_http\__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#     345 def _do_request(
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#     347 ):  # pylint: disable=unused-argument
#     348     """Low-level helper:  perform the actual API request over HTTP.
#     349
#     350     Allows batch context managers to override and defer a request.
#    (...)
#     377     :returns: The HTTP response.
#     378     """
# --> 379     return self.http.request(
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#     381     )
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\auth\transport\requests.py:538, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     535 remaining_time = max_allowed_time
#     537 with TimeoutGuard(remaining_time) as guard:
# --> 538     self.credentials.before_request(auth_request, method, url, request_headers)
#     539 remaining_time = guard.remaining_timeout
#     541 with TimeoutGuard(remaining_time) as guard:
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\auth\credentials.py:175, in Credentials.before_request(self, request, method, url, headers)
#     171 # pylint: disable=unused-argument
#     172 # (Subclasses may use these arguments to ascertain information about
#     173 # the http request.)
#     174 if not self.valid:
# --> 175     self.refresh(request)
#     176 metrics.add_metric_header(headers, self._metric_header_for_usage())
#     177 self.apply(headers)
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\oauth2\credentials.py:344, in Credentials.refresh(self, request)
#     326 if (
#     327     self._refresh_token is None
#     328     or self._token_uri is None
#     329     or self._client_id is None
#     330     or self._client_secret is None
#     331 ):
#     332     raise exceptions.RefreshError(
#     333         "The credentials do not contain the necessary fields need to "
#     334         "refresh the access token. You must specify refresh_token, "
#     335         "token_uri, client_id, and client_secret."
#     336     )
#     338 (
#     339     access_token,
#     340     refresh_token,
#     341     expiry,
#     342     grant_response,
#     343     rapt_token,
# --> 344 ) = reauth.refresh_grant(
#     345     request,
#     346     self._token_uri,
#     347     self._refresh_token,
#     348     self._client_id,
#     349     self._client_secret,
#     350     scopes=scopes,
#     351     rapt_token=self._rapt_token,
#     352     enable_reauth_refresh=self._enable_reauth_refresh,
#     353 )
#     355 self.token = access_token
#     356 self.expiry = expiry
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\oauth2\reauth.py:365, in refresh_grant(request, token_uri, refresh_token, client_id, client_secret, scopes, rapt_token, enable_reauth_refresh)
#     356     (
#     357         response_status_ok,
#     358         response_data,
#    (...)
#     361         request, token_uri, body, headers=metrics_header
#     362     )
#     364 if not response_status_ok:
# --> 365     _client._handle_error_response(response_data, retryable_error)
#     366 return _client._handle_refresh_grant_response(response_data, refresh_token) + (
#     367     rapt_token,
#     368 )
#
# File c:\Users\smvin\Documents\Python_training\.myenv\lib\site-packages\google\oauth2\_client.py:72, in _handle_error_response(response_data, retryable_error)
#      69 except (KeyError, ValueError):
#      70     error_details = json.dumps(response_data)
# ---> 72 raise exceptions.RefreshError(
#      73     error_details, response_data, retryable=retryable_error
#      74 )
#
# RefreshError: ('invalid_grant: Bad Request', {'error': 'invalid_grant', 'error_description': 'Bad Request'})
