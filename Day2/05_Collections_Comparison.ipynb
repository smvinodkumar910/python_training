# %% [markdown]
# ### Comparison of All Collection Datatypes

# %%
from IPython.display import Image

# Display an image from a file path
# Image(filename='python_comparison.jpeg')

# %%
Image(filename='Collections_comparison.png')
